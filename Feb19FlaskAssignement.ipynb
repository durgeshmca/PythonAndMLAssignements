# %% [markdown]
# # Feb 19 Flask Assignement

# %% [markdown]
# ## Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# ### Flask framework is a python based framework which is lightweght and used to create small WEB applications.It is a micro web framework written in Python.
# ### Advantages of flask
# #### Scalable
# #### Flexible
# #### Easy to negotiate
# #### Lightweight
# #### Well Documentation

# %% [markdown]
# ## Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# from flask import Flask
# from flask import request
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return "<h1>Hello, World!</h1>"
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:1597eea3-7f2e-485d-a8ab-57fc40f12a77.png)!

# %% [markdown]
# ## Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# ### App routing is a way of providing URL to the functions in flasks. Each url defines which function is to handle the request coming to that route.
# ### The app route() decorator to binds a function to a URL.

# %% [markdown]
# ## Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# ### Company Name: ABC Corporation
# ### Location: India
# #### Contact Detail: 999-999-9999

# %% [markdown]
# :
#
#     from flask import Flask
#
#     app = Flask(__name__)
#
#     @app.route("/")
#     def info():
#         return '''<b>Company Name:</b> ABC Corporation<br>
#     <b>Location</b>: India<br>
#     <b>Contact Detail</b>: 999-999-9999'''
#
#     @app.route("/welcome")
#     def welcome():
#         return '''<h2>Welcome to ABC Corporation</h2>'''
#
#     if __name__=="__main__":
#         app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:a04a26e8-7979-4c31-8272-365b926cb538.png)

# %% [markdown]
# ![image.png](attachment:202f37ef-9a8a-47c2-9543-5754043ee381.png)

# %% [markdown]
# ## Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# ### Function url_for() is used to build url in Flask. It build a URL to a specific function. It accepts the name of the function as its first argument and any number of keyword arguments, each corresponding to a variable part of the URL rule. Unknown variable parts are appended to the URL as query parameters.

# %% [markdown]
# :
#
#     from flask import url_for
#     from flask import Flask
#
#     app = Flask(__name__)
#
#
#     @app.route('/')
#     def index():
#         return 'index page'
#
#     @app.route('/login')
#     def login():
#         return 'login page'
#
#     @app.route('/user/<username>')
#     def profile(username):
#         return f'{username}\'s profile'
#
#     with app.test_request_context():
#         print(url_for('index'))
#         print(url_for('login'))
#         print(url_for('login', next='Durgesh'))
#         print(url_for('profile', username='abc'))

# %% [markdown]
# ![image.png](attachment:0f4121fd-47d4-4c71-9d68-228b6704529e.png)
