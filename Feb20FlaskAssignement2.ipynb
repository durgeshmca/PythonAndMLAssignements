# %% [markdown]
# # Flask Assignement 2

# %% [markdown]
# ## Q1. Explain GET and POST methods.

# %% [markdown]
# ### GET method sends form data as pasrt of url and open to all.
# ### Like if we have input in form with name username and email then it sends data to web server in url like
# #### https://blue-fireman-vynaj.pwskills.app:5000?username=abc&email=abc@example.com
# ### POST method sends form data in the body of the HTTP and is more secure than GET method

# %% [markdown]
# ## Q2. Why is request used in Flask?

# %% [markdown]
# ### request in Flask is used to get the data send to the server in the request packet .
# ### Data can be using get method or post method , in the form or as the parameter of the url.

# %% [markdown]
# ## Q3. Why is redirect() used in Flask?

# %% [markdown]
# ### redirect() method is used to redirect to a different URL. For Example when a user is successfully loged in then we redirect him to dashboard.
# ### Or if a user trying to access dashboard directly then we check if he is logged in if not then redirect to login page.
# app.redirect('/login')

# %% [markdown]
# ## Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# ### Templates are User Interface consists of HTML and css which have some varibles added in it resides in templates directory.The method render_template() render these templates by parsing the variables values to the browser.

# %% [markdown]
# :
#
#     @app.render_template('index.html',result=result)

# %% [markdown]
# ## Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# :
#
#     from flask import Flask,json,request
#
#     app = Flask(__name__)
#
#     @app.route('/reverse')
#     def reverse():
#         string = request.json['string']
#         return {
#             "reverse" : string[::-1]
#         }
#     if __name__=="__main__":
#         app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:6be8b878-f5fd-437c-919e-207c44ad5ad3.png)
